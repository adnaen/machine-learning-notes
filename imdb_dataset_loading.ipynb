# %% [markdown]
# <a href="https://colab.research.google.com/github/adnaen/machine-learning-notes/blob/main/imdb_dataset_loading.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import pandas as pd
import torch
from torch.utils.data import Dataset, DataLoader
from torch.nn.utils.rnn import pad_sequence
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv("/content/drive/MyDrive/Datasets/IMDB Dataset.csv", nrows=5000)
df.head()
# Out:
#                                               review sentiment
# 0  One of the other reviewers has mentioned that ...  positive
# 1  A wonderful little production. <br /><br />The...  positive
# 2  I thought this was a wonderful way to spend ti...  positive
# 3  Basically there's a family where a little boy ...  negative
# 4  Petter Mattei's "Love in the Time of Money" is...  positive

# %%
df["sentiment"].value_counts()
# Out:
# sentiment
# negative    2532
# positive    2468
# Name: count, dtype: int64

# %%
positive_df = df[df["sentiment"] == "positive"].sample(2000)
negative_df = df[df["sentiment"] == "negative"].sample(2000)

df = pd.concat([positive_df, negative_df], ignore_index=True)
df.shape
# Out:
# (4000, 2)

# %% [markdown]
# we know that, nn.RNN can't understand text. so we need to encode the text into VOCCAB index, lets create custome voccab storage

# %%
class Vocab:
    def __init__(self, VOCAB_SIZE: int = 10000) -> None:
        self.vocab: dict[str, int] = {"PAD": 0}
        self._current_value: int = 1
        self.VOCAB_SIZE = VOCAB_SIZE

    def add(self, sentence: list[str]) -> bool:

        if not isinstance(sentence, list):
            sentence = sentence.split()

        for token in sentence:
            if self._current_value + 1 >= self.VOCAB_SIZE:
                return False

            if self.is_exists(token):
                continue

            self.vocab[token] = self._current_value
            self._current_value += 1

        return True

    def is_exists(self, token: str) -> bool:
        return True if (
            token in self.vocab.keys()
        ) else (
            False
        )

    def __len__(self) -> int:
        return len(self.vocab.keys())

    def __getitem__(self, idx: str) -> int:
        if not self.is_exists(idx):
            return 0
        return self.vocab[idx]

    def __repr__(self) -> str:
        return str(self.vocab.items())

# %%
def clean_text(text: str) -> str:
    text = text.lower()
    return " ".join(re.findall("[a-z]+", text))

# %%
df["cleaned_review"] = df["review"].apply(clean_text)
df = df.drop(columns=["review"])
df.head()
# Out:
#   sentiment                                     cleaned_review
# 0  positive  this may just be the most nostalgic journey ba...
# 1  positive  what seemed at first just another introverted ...
# 2  positive  my wife is a mental health therapist and we wa...
# 3  positive  okay that was just brilliant i wish that the r...
# 4  positive  this is a really fun breezy light hearted roma...

# %%
vocab = Vocab()
for sentence in df["cleaned_review"]:
    vocab.add(sentence)

# %%
vocab # our own vocab!
# Out:
# dict_items([('PAD', 0), ('this', 1), ('may', 2), ('just', 3), ('be', 4), ('the', 5), ('most', 6), ('nostalgic', 7), ('journey', 8), ('back', 9), ('in', 10), ('time', 11), ('through', 12), ('to', 13), ('when', 14), ('one', 15), ('s', 16), ('childhood', 17), ('starts', 18), ('a', 19), ('reminiscences', 20), ('forth', 21), ('onwards', 22), ('upwards', 23), ('forwards', 24), ('backwards', 25), ('up', 26), ('down', 27), ('all', 28), ('around', 29), ('boy', 30), ('jimmy', 31), ('h', 32), ('r', 33), ('puffinstuff', 34), ('dr', 35), ('blinky', 36), ('cling', 37), ('clang', 38), ('ludicrous', 39), ('lion', 40), ('even', 41), ('evil', 42), ('witchie', 43), ('poo', 44), ('too', 45), ('latter', 46), ('day', 47), ('inspirations', 48), ('of', 49), ('lidsville', 50), ('brady', 51), ('kids', 52), ('saturday', 53), ('morning', 54), ('preview', 55), ('special', 56), ('sigmund', 57), ('sea', 58), ('monsters', 59), ('and', 60), ('land', 61), ('lost', 62), ('both', 63), ('new', 64), ('old', 65), ('are', 66), ('what', 67), ('very', 68), ('show', 69), ('bridged', 70), ('gap', 71), ('as', 72), ('well', 73), ('donny', 74), ('marie', 75), ('bunch', 76), ('variety', 77), ('hour', 78), ('k', 79), ('paul', 80), ('lynde', 81), ('halloween', 82), ('maybe', 83), ('other', 84), ('things', 85), ('between', 86), ('beyond', 87), ('buck', 88), ('keeps', 89), ('on', 90), ('moving', 91), ('expectations', 92), ('unexpected', 93), ('bounds', 94), ('now', 95), ('we', 96), ('get', 97), ('updated', 98), ('march', 99), ('know', 100), ('that', 101), ('jack', 102), ('wild', 103), ('gone', 104), ('so', 105), ('it', 106), ('make', 107), ('more', 108), ('symbolic', 109), ('for', 110), ('us', 111), ('really', 112), ('including', 113), ('august', 114), ('guest', 115), ('stars', 116), ('himself', 117), ('episode', 118), ('does', 119), ('recall', 120), ('journeys', 121), ('syd', 122), ('marty', 123), ('kroft', 124), ('characters', 125), ('goodtime', 126), ('club', 127), ('etc', 128), ('truthfully', 129), ('stephen', 130), ('steve', 131), ('g', 132), ('baer', 133), ('ste', 134), ('framingham', 135), ('ma', 136), ('usa', 137), ('seemed', 138), ('at', 139), ('first', 140), ('another', 141), ('introverted', 142), ('french', 143), ('flick', 144), ('offering', 145), ('no', 146), ('than', 147), ('baleful', 148), ('sentiment', 149), ('became', 150), ('me', 151), ('second', 152), ('viewing', 153), ('genuinely', 154), ('insightful', 155), ('quite', 156), ('satisfying', 157), ('presentation', 158), ('br', 159), ('spoiler', 160), ('sorts', 161), ('follows', 162), ('poor', 163), ('cedric', 164), ('he', 165), ('apparently', 166), ('didn', 167), ('t', 168), ('hit', 169), ('him', 170), ('audience', 171), ('were', 172), ('caught', 173), ('beautiful', 174), ('romantic', 175), ('story', 176), ('only', 177), ('led', 178), ('into', 179), ('dark', 180), ('reality', 181), ('mismatch', 182), ('these', 183), ('two', 184), ('guys', 185), ('belong', 186), ('together', 187), ('from', 188), ('their', 189), ('ambiguous', 190), ('encounter', 191), ('much', 192), ('mathieu', 193), ('sexually', 194), ('attracted', 195), ('each', 196), ('absence', 197), ('deeper', 198), ('emotional', 199), ('tie', 200), ('made', 201), ('impossible', 202), ('an', 203), ('intellectual', 204), ('being', 205), ('find', 206), ('fulfillment', 207), ('sharing', 208), ('life', 209), ('with', 210), ('someone', 211), ('whose', 212), ('sensibilities', 213), ('attuned', 214), ('carnival', 215), ('festivities', 216), ('romps', 217), ('beach', 218), ('purely', 219), ('technical', 220), ('note', 221), ('i', 222), ('loved', 223), ('camera', 224), ('action', 225), ('film', 226), ('subtitles', 227), ('totally', 228), ('unnecessary', 229), ('though', 230), ('my', 231), ('is', 232), ('presque', 233), ('rien', 234), ('could', 235), ('watch', 236), ('again', 237), ('without', 238), ('annoying', 239), ('english', 240), ('translation', 241), ('enjoy', 242), ('was', 243), ('polished', 244), ('professionally', 245), ('motion', 246), ('picture', 247), ('ma ...

# %%
def to_vocab_idx(text: str) -> torch.Tensor:
    if not isinstance(text, list):
        text = text.split()

    return torch.tensor([vocab[token] for token in text])

# %%
df["vocab_idx"] = df["cleaned_review"].apply(to_vocab_idx)
df.head()
# Out:
#   sentiment                                     cleaned_review  \
# 0  positive  this may just be the most nostalgic journey ba...
# 1  positive  what seemed at first just another introverted ...
# 2  positive  my wife is a mental health therapist and we wa...
# 3  positive  okay that was just brilliant i wish that the r...
# 4  positive  this is a really fun breezy light hearted roma...
#
#                                            vocab_idx
# 0  [tensor(1), tensor(2), tensor(3), tensor(4), t...
# 1  [tensor(67), tensor(138), tensor(139), tensor(...
# 2  [tensor(231), tensor(256), tensor(232), tensor...
# 3  [tensor(297), tensor(101), tensor(243), tensor...
# 4  [tensor(1), tensor(232), tensor(19), tensor(11...

# %%
df["y"] = df["sentiment"].map({"positive" : 1, "negative": 0})
df = df.drop(columns=["sentiment"])
df.head()
# Out:
#                                       cleaned_review  \
# 0  this may just be the most nostalgic journey ba...
# 1  what seemed at first just another introverted ...
# 2  my wife is a mental health therapist and we wa...
# 3  okay that was just brilliant i wish that the r...
# 4  this is a really fun breezy light hearted roma...
#
#                                            vocab_idx  y
# 0  [tensor(1), tensor(2), tensor(3), tensor(4), t...  1
# 1  [tensor(67), tensor(138), tensor(139), tensor(...  1
# 2  [tensor(231), tensor(256), tensor(232), tensor...  1
# 3  [tensor(297), tensor(101), tensor(243), tensor...  1
# 4  [tensor(1), tensor(232), tensor(19), tensor(11...  1

# %%
x_train, x_test, y_train, y_test = train_test_split(
    df["vocab_idx"].values,
    torch.tensor(df["y"].values),
    test_size=0.2,
    random_state=2323,
    shuffle=True,
)

(x_train.shape, y_train.shape), (x_test.shape, y_test.shape)
# Out:
# (((3200,), torch.Size([3200])), ((800,), torch.Size([800])))

# %%
new_x_train = pad_sequence(x_train, padding_value=0).T
new_x_test = pad_sequence(x_test, padding_value=0).T

# %%
# prepare data with dataset and dataloader
class IMDBDataset(Dataset):
    def __init__(self, x: torch.Tensor, y: torch.Tensor) -> None:
        self.x = x
        self.y = y

    def __len__(self) -> int:
        return len(self.x)

    def __getitem__(self, idx: int) -> tuple:
        return self.x[idx], self.y[idx]

# %%
imdb_ds = IMDBDataset(x=new_x_train, y=y_train)
dataloader = DataLoader(dataset=imdb_ds, shuffle=True, batch_size=300)

# %%
len(dataloader)

# now data is ready with 11 batches
# Out:
# 11

# %%
class IMDBMoviewReviewRNN(torch.nn.Module):
    def __init__(self, embedding_dim, hidden_size: int) -> None:
        super().__init__()

        self.embedding = torch.nn.Embedding(
            num_embeddings=10000,
            embedding_dim=embedding_dim
            )
        self.rnn = torch.nn.RNN(
            input_size=embedding_dim,
            hidden_size=hidden_size,
            )

        self.linear = torch.nn.Linear(hidden_size, 1)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        embeddings = self.embedding(x)
        op, hidden = self.rnn(embeddings)
        logits = self.linear(hidden)
        return logits

# %%
model = IMDBMoviewReviewRNN(embedding_dim=3, hidden_size=5)

epochs: int = 200
criterion = torch.nn.CrossEntropyLoss()
optim = torch.optim.Adam(model.parameters())

model.train()
for ep in range(epochs):
    for batch_x, batch_y in dataloader:
        y_pred = model(batch_x)
        cre

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-53-7ec487064a7d> in <cell line: 0>()
# ----> 1 torch.argmax(torch.tensor([0.212]), dim=1)
#
# IndexError: Dimension out of range (expected to be in range of [-1, 0], but got 1)
